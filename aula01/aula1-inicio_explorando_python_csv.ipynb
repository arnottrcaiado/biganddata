# %%
# Abrindo e tratando dados .csv
# principios
# Prof. Arnott Ramos Caiado
# set-2020

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# verificando localização e conteúdo da(s) pasta(s)

# %%
! pwd
# Out:
# /home/usuario/Google Drive/DATASCIENCE/facsenac/biganddata/aula01

# %%
! ls -la .
# Out:
# total 184
# drwxrwxr-x 3 usuario usuario   4096 set  9 21:07 .
# drwxrwxr-x 7 usuario usuario   4096 set  2 02:58 ..
# -rw-rw-r-- 1 usuario usuario 115443 set  9 21:07 aula1-inicio_explorando_python_csv.ipynb
# drwxrwxr-x 2 usuario usuario   4096 set  9 15:07 .ipynb_checkpoints
# -rw-rw-r-- 1 usuario usuario  25419 set  9 16:54 Pesq_alunos_ntrat.csv
# -rw-rw-r-- 1 usuario usuario  25291 set  9 16:54 Pesq_alunos_trat.csv

# %%
# variavel com o caminho (path) e o nome do arquivo

# %%
dados = "Pesq_alunos_trat.csv"
dados_sujos = "Pesq_alunos_ntrat.csv"

# %%
# criando um dataframe pandas com o resultado do arquivo .csv

# %%
df = pd.read_csv( dados )
df2 = pd.read_csv( dados_sujos )

# %%
df.shape # tamanho do dataframe - 75 linhas por 13 colunas
df2.shape
# Out:
# (75, 13)

# %%
# mostrando as primeiras 10 linhas para conhecer um pouco

# %%
df.head(10)
# Out:
#   Sexo Estado Civil  \
# 0    F     Viuvo(a)
# 1    M  Solteiro(a)
# 2    M  Solteiro(a)
# 3    M    Namorando
# 4    M  Solteiro(a)
# 5    F  Solteiro(a)
# 6    M        Noivo
# 7    M  Solteiro(a)
# 8    M    Namorando
# 9    F  Solteiro(a)
#
#    Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )  \
# 0                                               1.67
# 1                                               1.74
# 2                                               1.70
# 3                                               1.89
# 4                                               1.80
# 5                                               1.63
# 6                                               1.83
# 7                                               1.67
# 8                                               1.60
# 9                                               1.65
#
#    Seu peso aproximado em kg  Idade      Curso#Periodo/Turno  \
# 0                       70.0     27  ADS#2Manha-PortoDigital
# 1                       68.0     22  ADS#2Manha-PortoDigital
# 2                       55.0     18  ADS#2Manha-PortoDigital
# 3                       60.0     19  ADS#2Manha-PortoDigital
# 4                       60.0     17  ADS#2Manha-PortoDigital
# 5                       58.0     20  ADS#2Manha-PortoDigital
# 6                       66.0     23  ADS#2Manha-PortoDigital
# 7                       80.0     27  ADS#2Manha-PortoDigital
# 8                       68.0     18  ADS#2Manha-PortoDigital
# 9                       64.0     18  ADS#2Manha-PortoDigital
#
#   Situação atual de trabalho  \
# 0           Estudando Apenas
# 1           Estudando Apenas
# 2           Estudando Apenas
# 3           Estudando Apenas
# 4           Estudando Apenas
# 5           Estudando Apenas
# 6           Estudando Apenas
# 7                Trabalhando
# 8           Estudando Apenas
# 9           Estudando Apenas
#
#   Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                               Java
# 1                    JavaScript, Python, PHP, C, C++
# 2                                   Java, JavaScript
# 3                        JavaScript, Python, C#, C++
# 4       Java, JavaScript, Python, R, PHP, C, C#, C++
# 5                        JavaScript, Python, PHP, C#
# 6                  Java, JavaScript, Python, PHP, C#
# 7                       Java, JavaScript, Python, C#
# 8                  Java, JavaScript, Python, PHP, C#
# 9                  Java, JavaScript, Python, PHP, C#
#
#   O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                  Estudar e correr
# 1                                 Exercícios físicos
# 2  Assistir filmes e conversar online com meus am...
# 3                                 Teatro e jogar lol
# 4               Arriscar no desenvolvimento de sites
# 5                                            Pedalar
# 6      Assistir filmes de ação e praticar musculação
# 7                      Continuar meus jogos de Vôlei
# 8          Jogar com amigos, assistir com a fámilia
# 9  Assistir filmes/séries e ir à praia quando for...
#
#   Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                         SmartPhone
# 1                               SmartPhone, NoteBook
# 2                               SmartPhone, NoteBook
# 3  SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                               SmartPhone, NoteBook
# 5                               SmartPhone, NoteBook
# 6                               SmartPhone, NoteBook
# 7  SmartPhone, NoteBook, Câmera de Video ( micro ...
# 8  SmartPhone, Micro Desktop, Microfone ( micro o...
# 9                               SmartPhone, NoteBook
#
#   Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                               3 a 5 horas semanais
# 1                               3 a 5 horas semanais
# 2                               3 a 5 horas semanais
# 3                              1 a 15 horas semanais
# 4                              6 a 10 horas semanais
# 5                               1 a 2 horas semanais
# 6  Depende do nível da atividade, houve algumas q...
# 7                               3 a 5 horas semanais
# 8                               3 a 5 horas semanais
# 9                              6 a 10 horas semanais
#
#   Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                  Segurança tecnologia ou pesquisa
# 1            UX/UI design, Desenvolvimento Front-end
# 2                            engenharia de software
# 3                               Programador de jogos
# 4            Na área de desenvolvimento web, backend
# 5                                            backend
# 6  Desenvolvimento mobile, inteligência artificia...
# 7                                  Segurança pública
# 8             Em progrmação web e segurança de dados
# 9    Não tenho certeza ainda, mas penso em Hardware.
#
#   Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                           Nenhum\n
# 1                                             Nenhum
# 2                                 Curso de java 120h
# 3  Curso de html avançado 15h, Desafio quarentena...
# 4                           Licenciatura em Biologia
# 5                                             nenhum
# 6                                       Python (40h)
# 7                             Lógica de programação
# 8                         Desafio quarentena - 60hrs
# 9              Nenhum curso. Mas sempre pesquisando.

# %%
# algumas estatisticas - método describe

# %%
df.describe()
# Out:
#        Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )  \
# count                                          74.000000
# mean                                            1.710405
# std                                             0.078312
# min                                             1.500000
# 25%                                             1.650000
# 50%                                             1.700000
# 75%                                             1.767500
# max                                             1.890000
#
#        Seu peso aproximado em kg      Idade
# count                  73.000000  75.000000
# mean                   70.849315  24.533333
# std                    15.863718   6.973567
# min                    32.000000  17.000000
# 25%                    60.000000  19.000000
# 50%                    69.000000  23.000000
# 75%                    78.000000  29.000000
# max                   140.000000  53.000000

# %%
# há diferenças entre os dois dataframes ?

# %%
# mostrar algumas medidas descritivas dos dados numéricos de um dataframe
# contagem
# média
# desvio padrão
# minimo
# máximo
df2.describe()
# Out:
#        Seu peso aproximado em kg      Idade
# count                  70.000000  75.000000
# mean                   71.071429  24.533333
# std                    16.165199   6.973567
# min                    32.000000  17.000000
# 25%                    60.000000  19.000000
# 50%                    70.000000  23.000000
# 75%                    79.500000  29.000000
# max                   140.000000  53.000000

# %%
# mostrando um grafico inicial - histograma de idades

# %%
df['Idade'].hist()

# %%
df2['Idade'].hist()

# %%
df['Seu peso aproximado em kg'].hist()

# %%
df2['Seu peso aproximado em kg'].hist()

# %%
# modificando o nome de colunas para simplificar / facilitar

# %%
df.rename(columns={'Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )': 'altura'})
# Out:
#    Sexo Estado Civil  altura  Seu peso aproximado em kg  Idade  \
# 0     F     Viuvo(a)    1.67                       70.0     27
# 1     M  Solteiro(a)    1.74                       68.0     22
# 2     M  Solteiro(a)    1.70                       55.0     18
# 3     M    Namorando    1.89                       60.0     19
# 4     M  Solteiro(a)    1.80                       60.0     17
# ..  ...          ...     ...                        ...    ...
# 70    M  Solteiro(a)    1.65                       64.0     31
# 71    F  Solteiro(a)    1.62                       51.0     19
# 72    M  Solteiro(a)    1.85                       70.0     22
# 73    M  Solteiro(a)    1.70                       64.0     22
# 74    M  Solteiro(a)    1.70                       62.0     21
#
#         Curso#Periodo/Turno Situação atual de trabalho  \
# 0   ADS#2Manha-PortoDigital           Estudando Apenas
# 1   ADS#2Manha-PortoDigital           Estudando Apenas
# 2   ADS#2Manha-PortoDigital           Estudando Apenas
# 3   ADS#2Manha-PortoDigital           Estudando Apenas
# 4   ADS#2Manha-PortoDigital           Estudando Apenas
# ..                      ...                        ...
# 70               ADS#3Manha           Estudando Apenas
# 71               ADS#3Manha           Estudando Apenas
# 72               ADS#3Manha           Estudando Apenas
# 73               ADS#3Manha           Estudando Apenas
# 74               ADS#3Manha           Estudando Apenas
#
#    Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                                Java
# 1                     JavaScript, Python, PHP, C, C++
# 2                                    Java, JavaScript
# 3                         JavaScript, Python, C#, C++
# 4        Java, JavaScript, Python, R, PHP, C, C#, C++
# ..                                                ...
# 70                                 JavaScript, Python
# 71                                   Java, Python, C#
# 72                                   Java, Python, C#
# 73                                  Java, Python, PHP
# 74                   Java, JavaScript, Python, PHP, C
#
#    O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                   Estudar e correr
# 1                                  Exercícios físicos
# 2   Assistir filmes e conversar online com meus am...
# 3                                  Teatro e jogar lol
# 4                Arriscar no desenvolvimento de sites
# ..                                                ...
# 70                Assistir series, jogar vídeo games.
# 71  ler bastante, aprender novas linguagens e algu...
# 72                                Navegar na internet
# 73                                     CRIAR PROJETOS
# 74                                 Aproveitar o tempo
#
#    Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                          SmartPhone
# 1                                SmartPhone, NoteBook
# 2                                SmartPhone, NoteBook
# 3   SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                                SmartPhone, NoteBook
# ..                                                ...
# 70                               SmartPhone, NoteBook
# 71  NoteBook, Câmera de Video ( micro ou notebook ...
# 72                               SmartPhone, NoteBook
# 73                               SmartPhone, NoteBook
# 74                               SmartPhone, NoteBook
#
#    Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                                3 a 5 horas semanais
# 1                                3 a 5 horas semanais
# 2                                3 a 5 horas semanais
# 3                               1 a 15 horas semanais
# 4                               6 a 10 horas semanais
# ..                                                ...
# 70                               3 a 5 horas semanais
# 71                              6 a 10 horas semanais
# 72                               3 a 5 horas semanais
# 73                               1 a 2 horas semanais
# 74                             10 a 15 horas semanais
#
#    Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                   Segurança tecnologia ou pesquisa
# 1             UX/UI design, Desenvolvimento Front-end
# 2                             engenharia de software
# 3                                Programador de jogos
# 4             Na área de desenvolvimento web, backend
# ..                                                ...
# 70  Ainda estou analisando o que eu irei seguir, m...
# 71           segurança da informação e Dev Full Stack
# 72                               Programação back-end
# 73  BANCO DE DADOS, PREVENÇÃO DE INVASÃO, ÁREAS RE...
# 74  Engenharia civil com foco em projetos de segur...
#
#    Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                            Nenhum\n
# 1                                              Nenhum
# 2                                  Curso de java 120h
# 3   Curso de html avançado 15h, Desafio quarentena...
# 4                            Licenciatura em Biologia
# ..                                                ...
# 70                                            Nenhum.
# 71  webnar - Primeiros passos em oracle (4h)\nOmni...
# 72                                             nenhum
# 73                                    EXCEL AVANÇADO.
# 74                    Bacharelado em Engenharia civil
#
# [75 rows x 13 columns]

# %%
df.head(10)
# Out:
#   Sexo Estado Civil  \
# 0    F     Viuvo(a)
# 1    M  Solteiro(a)
# 2    M  Solteiro(a)
# 3    M    Namorando
# 4    M  Solteiro(a)
# 5    F  Solteiro(a)
# 6    M        Noivo
# 7    M  Solteiro(a)
# 8    M    Namorando
# 9    F  Solteiro(a)
#
#    Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )  \
# 0                                               1.67
# 1                                               1.74
# 2                                               1.70
# 3                                               1.89
# 4                                               1.80
# 5                                               1.63
# 6                                               1.83
# 7                                               1.67
# 8                                               1.60
# 9                                               1.65
#
#    Seu peso aproximado em kg  Idade      Curso#Periodo/Turno  \
# 0                       70.0     27  ADS#2Manha-PortoDigital
# 1                       68.0     22  ADS#2Manha-PortoDigital
# 2                       55.0     18  ADS#2Manha-PortoDigital
# 3                       60.0     19  ADS#2Manha-PortoDigital
# 4                       60.0     17  ADS#2Manha-PortoDigital
# 5                       58.0     20  ADS#2Manha-PortoDigital
# 6                       66.0     23  ADS#2Manha-PortoDigital
# 7                       80.0     27  ADS#2Manha-PortoDigital
# 8                       68.0     18  ADS#2Manha-PortoDigital
# 9                       64.0     18  ADS#2Manha-PortoDigital
#
#   Situação atual de trabalho  \
# 0           Estudando Apenas
# 1           Estudando Apenas
# 2           Estudando Apenas
# 3           Estudando Apenas
# 4           Estudando Apenas
# 5           Estudando Apenas
# 6           Estudando Apenas
# 7                Trabalhando
# 8           Estudando Apenas
# 9           Estudando Apenas
#
#   Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                               Java
# 1                    JavaScript, Python, PHP, C, C++
# 2                                   Java, JavaScript
# 3                        JavaScript, Python, C#, C++
# 4       Java, JavaScript, Python, R, PHP, C, C#, C++
# 5                        JavaScript, Python, PHP, C#
# 6                  Java, JavaScript, Python, PHP, C#
# 7                       Java, JavaScript, Python, C#
# 8                  Java, JavaScript, Python, PHP, C#
# 9                  Java, JavaScript, Python, PHP, C#
#
#   O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                  Estudar e correr
# 1                                 Exercícios físicos
# 2  Assistir filmes e conversar online com meus am...
# 3                                 Teatro e jogar lol
# 4               Arriscar no desenvolvimento de sites
# 5                                            Pedalar
# 6      Assistir filmes de ação e praticar musculação
# 7                      Continuar meus jogos de Vôlei
# 8          Jogar com amigos, assistir com a fámilia
# 9  Assistir filmes/séries e ir à praia quando for...
#
#   Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                         SmartPhone
# 1                               SmartPhone, NoteBook
# 2                               SmartPhone, NoteBook
# 3  SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                               SmartPhone, NoteBook
# 5                               SmartPhone, NoteBook
# 6                               SmartPhone, NoteBook
# 7  SmartPhone, NoteBook, Câmera de Video ( micro ...
# 8  SmartPhone, Micro Desktop, Microfone ( micro o...
# 9                               SmartPhone, NoteBook
#
#   Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                               3 a 5 horas semanais
# 1                               3 a 5 horas semanais
# 2                               3 a 5 horas semanais
# 3                              1 a 15 horas semanais
# 4                              6 a 10 horas semanais
# 5                               1 a 2 horas semanais
# 6  Depende do nível da atividade, houve algumas q...
# 7                               3 a 5 horas semanais
# 8                               3 a 5 horas semanais
# 9                              6 a 10 horas semanais
#
#   Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                  Segurança tecnologia ou pesquisa
# 1            UX/UI design, Desenvolvimento Front-end
# 2                            engenharia de software
# 3                               Programador de jogos
# 4            Na área de desenvolvimento web, backend
# 5                                            backend
# 6  Desenvolvimento mobile, inteligência artificia...
# 7                                  Segurança pública
# 8             Em progrmação web e segurança de dados
# 9    Não tenho certeza ainda, mas penso em Hardware.
#
#   Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                           Nenhum\n
# 1                                             Nenhum
# 2                                 Curso de java 120h
# 3  Curso de html avançado 15h, Desafio quarentena...
# 4                           Licenciatura em Biologia
# 5                                             nenhum
# 6                                       Python (40h)
# 7                             Lógica de programação
# 8                         Desafio quarentena - 60hrs
# 9              Nenhum curso. Mas sempre pesquisando.

# %%
# alterando o dataframe com a nova nomenclatura

# %%
df = df.rename(columns={'Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )': 'altura'})

# %%
df['altura'].hist()

# %%
df['altura'] =  pd.to_numeric(df['altura'])

# %%
df['altura'].mean()
# Out:
# 1.7104054054054063

# %%
df2 = df2.rename(columns={'Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )': 'altura'})
df2['altura'].hist()

# %%
df2['altura'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-51f6bb8c2e1e> in <module>
# ----> 1 df2['altura'].mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     540         dtype_count = dtype
#     541     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 542     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     543
#     544     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %%
# por que o erro ?

# %%
df2
# Out:
#    Sexo Estado Civil  \
# 0     F     Viuvo(a)
# 1     M  Solteiro(a)
# 2     M  Solteiro(a)
# 3     M    Namorando
# 4     M  Solteiro(a)
# ..  ...          ...
# 70    M  Solteiro(a)
# 71    F  Solteiro(a)
# 72    M  Solteiro(a)
# 73    M  Solteiro(a)
# 74    M  Solteiro(a)
#
#    Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )  \
# 0                                                1,67
# 1                                                1,74
# 2                                                 1,7
# 3                                                1,89
# 4                                                 1,8
# ..                                                ...
# 70                                                NaN
# 71                                               1,62
# 72                                               1,85
# 73                                             170 CM
# 74                                                1,7
#
#     Seu peso aproximado em kg  Idade      Curso#Periodo/Turno  \
# 0                        70.0     27  ADS#2Manha-PortoDigital
# 1                        68.0     22  ADS#2Manha-PortoDigital
# 2                        55.0     18  ADS#2Manha-PortoDigital
# 3                        60.0     19  ADS#2Manha-PortoDigital
# 4                        60.0     17  ADS#2Manha-PortoDigital
# ..                        ...    ...                      ...
# 70                        NaN     31               ADS#3Manha
# 71                       51.0     19               ADS#3Manha
# 72                       70.0     22               ADS#3Manha
# 73                       64.0     22               ADS#3Manha
# 74                       62.0     21               ADS#3Manha
#
#    Situação atual de trabalho  \
# 0            Estudando Apenas
# 1            Estudando Apenas
# 2            Estudando Apenas
# 3            Estudando Apenas
# 4            Estudando Apenas
# ..                        ...
# 70           Estudando Apenas
# 71           Estudando Apenas
# 72           Estudando Apenas
# 73           Estudando Apenas
# 74           Estudando Apenas
#
#    Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                                Java
# 1                     JavaScript, Python, PHP, C, C++
# 2                                    Java, JavaScript
# 3                         JavaScript, Python, C#, C++
# 4        Java, JavaScript, Python, R, PHP, C, C#, C++
# ..                                                ...
# 70                                 JavaScript, Python
# 71                                   Java, Python, C#
# 72                                   Java, Python, C#
# 73                                  Java, Python, PHP
# 74                   Java, JavaScript, Python, PHP, C
#
#    O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                   Estudar e correr
# 1                                  Exercícios físicos
# 2   Assistir filmes e conversar online com meus am...
# 3                                  Teatro e jogar lol
# 4                Arriscar no desenvolvimento de sites
# ..                                                ...
# 70                Assistir series, jogar vídeo games.
# 71  ler bastante, aprender novas linguagens e algu...
# 72                                Navegar na internet
# 73                                     CRIAR PROJETOS
# 74                                 Aproveitar o tempo
#
#    Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                          SmartPhone
# 1                                SmartPhone, NoteBook
# 2                                SmartPhone, NoteBook
# 3   SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                                SmartPhone, NoteBook
# ..                                                ...
# 70                               SmartPhone, NoteBook
# 71  NoteBook, Câmera de Video ( micro ou notebook ...
# 72                               SmartPhone, NoteBook
# 73                               SmartPhone, NoteBook
# 74                               SmartPhone, NoteBook
#
#    Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                                3 a 5 horas semanais
# 1                                3 a 5 horas semanais
# 2                                3 a 5 horas semanais
# 3                               1 a 15 horas semanais
# 4                               6 a 10 horas semanais
# ..                                                ...
# 70                               3 a 5 horas semanais
# 71                              6 a 10 horas semanais
# 72                               3 a 5 horas semanais
# 73                               1 a 2 horas semanais
# 74                             10 a 15 horas semanais
#
#    Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                   Segurança tecnologia ou pesquisa
# 1             UX/UI design, Desenvolvimento Front-end
# 2                             engenharia de software
# 3                                Programador de jogos
# 4             Na área de desenvolvimento web, backend
# ..                                                ...
# 70  Ainda estou analisando o que eu irei seguir, m...
# 71           segurança da informação e Dev Full Stack
# 72                               Programação back-end
# 73  BANCO DE DADOS, PREVENÇÃO DE INVASÃO, ÁREAS RE...
# 74  Engenharia civil com foco em projetos de segur...
#
#    Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                            Nenhum\n
# 1                                              Nenhum
# 2                                  Curso de java 120h
# 3   Curso de html avançado 15h, Desafio quarentena...
# 4                            Licenciatura em Biologia
# ..                                                ...
# 70                                            Nenhum.
# 71  webnar - Primeiros passos em oracle (4h)\nOmni...
# 72                                             nenhum
# 73                                    EXCEL AVANÇADO.
# 74                    Bacharelado em Engenharia civil
#
# [75 rows x 13 columns]

# %%
# substituindo , por .
df2['altura'] = df2['altura'].str.replace(',','.')

# %%
df2
# Out:
#    Sexo Estado Civil  altura  Seu peso aproximado em kg  Idade  \
# 0     F     Viuvo(a)    1.67                       70.0     27
# 1     M  Solteiro(a)    1.74                       68.0     22
# 2     M  Solteiro(a)     1.7                       55.0     18
# 3     M    Namorando    1.89                       60.0     19
# 4     M  Solteiro(a)     1.8                       60.0     17
# ..  ...          ...     ...                        ...    ...
# 70    M  Solteiro(a)     NaN                        NaN     31
# 71    F  Solteiro(a)    1.62                       51.0     19
# 72    M  Solteiro(a)    1.85                       70.0     22
# 73    M  Solteiro(a)  170 CM                       64.0     22
# 74    M  Solteiro(a)     1.7                       62.0     21
#
#         Curso#Periodo/Turno Situação atual de trabalho  \
# 0   ADS#2Manha-PortoDigital           Estudando Apenas
# 1   ADS#2Manha-PortoDigital           Estudando Apenas
# 2   ADS#2Manha-PortoDigital           Estudando Apenas
# 3   ADS#2Manha-PortoDigital           Estudando Apenas
# 4   ADS#2Manha-PortoDigital           Estudando Apenas
# ..                      ...                        ...
# 70               ADS#3Manha           Estudando Apenas
# 71               ADS#3Manha           Estudando Apenas
# 72               ADS#3Manha           Estudando Apenas
# 73               ADS#3Manha           Estudando Apenas
# 74               ADS#3Manha           Estudando Apenas
#
#    Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                                Java
# 1                     JavaScript, Python, PHP, C, C++
# 2                                    Java, JavaScript
# 3                         JavaScript, Python, C#, C++
# 4        Java, JavaScript, Python, R, PHP, C, C#, C++
# ..                                                ...
# 70                                 JavaScript, Python
# 71                                   Java, Python, C#
# 72                                   Java, Python, C#
# 73                                  Java, Python, PHP
# 74                   Java, JavaScript, Python, PHP, C
#
#    O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                   Estudar e correr
# 1                                  Exercícios físicos
# 2   Assistir filmes e conversar online com meus am...
# 3                                  Teatro e jogar lol
# 4                Arriscar no desenvolvimento de sites
# ..                                                ...
# 70                Assistir series, jogar vídeo games.
# 71  ler bastante, aprender novas linguagens e algu...
# 72                                Navegar na internet
# 73                                     CRIAR PROJETOS
# 74                                 Aproveitar o tempo
#
#    Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                          SmartPhone
# 1                                SmartPhone, NoteBook
# 2                                SmartPhone, NoteBook
# 3   SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                                SmartPhone, NoteBook
# ..                                                ...
# 70                               SmartPhone, NoteBook
# 71  NoteBook, Câmera de Video ( micro ou notebook ...
# 72                               SmartPhone, NoteBook
# 73                               SmartPhone, NoteBook
# 74                               SmartPhone, NoteBook
#
#    Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                                3 a 5 horas semanais
# 1                                3 a 5 horas semanais
# 2                                3 a 5 horas semanais
# 3                               1 a 15 horas semanais
# 4                               6 a 10 horas semanais
# ..                                                ...
# 70                               3 a 5 horas semanais
# 71                              6 a 10 horas semanais
# 72                               3 a 5 horas semanais
# 73                               1 a 2 horas semanais
# 74                             10 a 15 horas semanais
#
#    Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                   Segurança tecnologia ou pesquisa
# 1             UX/UI design, Desenvolvimento Front-end
# 2                             engenharia de software
# 3                                Programador de jogos
# 4             Na área de desenvolvimento web, backend
# ..                                                ...
# 70  Ainda estou analisando o que eu irei seguir, m...
# 71           segurança da informação e Dev Full Stack
# 72                               Programação back-end
# 73  BANCO DE DADOS, PREVENÇÃO DE INVASÃO, ÁREAS RE...
# 74  Engenharia civil com foco em projetos de segur...
#
#    Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                            Nenhum\n
# 1                                              Nenhum
# 2                                  Curso de java 120h
# 3   Curso de html avançado 15h, Desafio quarentena...
# 4                            Licenciatura em Biologia
# ..                                                ...
# 70                                            Nenhum.
# 71  webnar - Primeiros passos em oracle (4h)\nOmni...
# 72                                             nenhum
# 73                                    EXCEL AVANÇADO.
# 74                    Bacharelado em Engenharia civil
#
# [75 rows x 13 columns]

# %%
len(df2)
for i in range(len( df2 )):
    print( df2['altura'][i])
# Out:
# 1.67
# 1.74
# 1.7
# 1.89
# 1.8
# 1.63
# 1.83
# 1.67
# 1.6
# 1.65
# 1.7
# 1.78
# 1.6
# 1.75
# 1.73
# 1.7
# 1.71
# 1.61
# 1.78
# 172
# 1.7
# nan
# 1.82
# 1.65
# 1.78
# 1.75
# 1.85
# 1.73
# 1.6
# 1.67
# 1.77
# 1.81
# 1.7
# 1.79
# 1.53
# 1.81
# 1.66
# 1.75
# 1.79
# 1.74
# 1.67
# 1.79
# 1.74
# 1.65
# 1.76
# 1.65
# 1.65
# 1.65
# 1.67
# 1.7
# 1.65
# 1.76
# 1.68
# 1.75
# 1.68
# 1.55
# 1.74
# 1.8
# 1.65
# 1.8
# 1.5
# 1.72
# 1.67
# 1.74
# 1.82
# 1.7
# 1.8
# 1.73
# 1.6
# nan
# nan
# 1.62
# 1.85
# 170 CM
# 1.7

# %%
df2['altura'] =  pd.to_numeric(df2['altura'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "170 CM"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-2a3b9fd290a2> in <module>
# ----> 1 df2['altura'] =  pd.to_numeric(df2['altura'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "170 CM" at position 73

# %%
df2['altura'][73]=1.73
# Out:
# /home/usuario/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['altura'][73]
# Out:
# 1.73

# %%
df2['altura'] =  pd.to_numeric(df2['altura'])

# %%
df2['altura'].mean()
# Out:
# 4.077916666666668

# %%
df2.describe()
# Out:
#            altura  Seu peso aproximado em kg      Idade
# count   72.000000                  70.000000  75.000000
# mean     4.077917                  71.071429  24.533333
# std     20.068690                  16.165199   6.973567
# min      1.500000                  32.000000  17.000000
# 25%      1.657500                  60.000000  19.000000
# 50%      1.715000                  70.000000  23.000000
# 75%      1.780000                  79.500000  29.000000
# max    172.000000                 140.000000  53.000000

# %%
df2
# Out:
#    Sexo Estado Civil  altura  Seu peso aproximado em kg  Idade  \
# 0     F     Viuvo(a)    1.67                       70.0     27
# 1     M  Solteiro(a)    1.74                       68.0     22
# 2     M  Solteiro(a)    1.70                       55.0     18
# 3     M    Namorando    1.89                       60.0     19
# 4     M  Solteiro(a)    1.80                       60.0     17
# ..  ...          ...     ...                        ...    ...
# 70    M  Solteiro(a)     NaN                        NaN     31
# 71    F  Solteiro(a)    1.62                       51.0     19
# 72    M  Solteiro(a)    1.85                       70.0     22
# 73    M  Solteiro(a)    1.73                       64.0     22
# 74    M  Solteiro(a)    1.70                       62.0     21
#
#         Curso#Periodo/Turno Situação atual de trabalho  \
# 0   ADS#2Manha-PortoDigital           Estudando Apenas
# 1   ADS#2Manha-PortoDigital           Estudando Apenas
# 2   ADS#2Manha-PortoDigital           Estudando Apenas
# 3   ADS#2Manha-PortoDigital           Estudando Apenas
# 4   ADS#2Manha-PortoDigital           Estudando Apenas
# ..                      ...                        ...
# 70               ADS#3Manha           Estudando Apenas
# 71               ADS#3Manha           Estudando Apenas
# 72               ADS#3Manha           Estudando Apenas
# 73               ADS#3Manha           Estudando Apenas
# 74               ADS#3Manha           Estudando Apenas
#
#    Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                                Java
# 1                     JavaScript, Python, PHP, C, C++
# 2                                    Java, JavaScript
# 3                         JavaScript, Python, C#, C++
# 4        Java, JavaScript, Python, R, PHP, C, C#, C++
# ..                                                ...
# 70                                 JavaScript, Python
# 71                                   Java, Python, C#
# 72                                   Java, Python, C#
# 73                                  Java, Python, PHP
# 74                   Java, JavaScript, Python, PHP, C
#
#    O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                   Estudar e correr
# 1                                  Exercícios físicos
# 2   Assistir filmes e conversar online com meus am...
# 3                                  Teatro e jogar lol
# 4                Arriscar no desenvolvimento de sites
# ..                                                ...
# 70                Assistir series, jogar vídeo games.
# 71  ler bastante, aprender novas linguagens e algu...
# 72                                Navegar na internet
# 73                                     CRIAR PROJETOS
# 74                                 Aproveitar o tempo
#
#    Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                          SmartPhone
# 1                                SmartPhone, NoteBook
# 2                                SmartPhone, NoteBook
# 3   SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                                SmartPhone, NoteBook
# ..                                                ...
# 70                               SmartPhone, NoteBook
# 71  NoteBook, Câmera de Video ( micro ou notebook ...
# 72                               SmartPhone, NoteBook
# 73                               SmartPhone, NoteBook
# 74                               SmartPhone, NoteBook
#
#    Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                                3 a 5 horas semanais
# 1                                3 a 5 horas semanais
# 2                                3 a 5 horas semanais
# 3                               1 a 15 horas semanais
# 4                               6 a 10 horas semanais
# ..                                                ...
# 70                               3 a 5 horas semanais
# 71                              6 a 10 horas semanais
# 72                               3 a 5 horas semanais
# 73                               1 a 2 horas semanais
# 74                             10 a 15 horas semanais
#
#    Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                   Segurança tecnologia ou pesquisa
# 1             UX/UI design, Desenvolvimento Front-end
# 2                             engenharia de software
# 3                                Programador de jogos
# 4             Na área de desenvolvimento web, backend
# ..                                                ...
# 70  Ainda estou analisando o que eu irei seguir, m...
# 71           segurança da informação e Dev Full Stack
# 72                               Programação back-end
# 73  BANCO DE DADOS, PREVENÇÃO DE INVASÃO, ÁREAS RE...
# 74  Engenharia civil com foco em projetos de segur...
#
#    Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                            Nenhum\n
# 1                                              Nenhum
# 2                                  Curso de java 120h
# 3   Curso de html avançado 15h, Desafio quarentena...
# 4                            Licenciatura em Biologia
# ..                                                ...
# 70                                            Nenhum.
# 71  webnar - Primeiros passos em oracle (4h)\nOmni...
# 72                                             nenhum
# 73                                    EXCEL AVANÇADO.
# 74                    Bacharelado em Engenharia civil
#
# [75 rows x 13 columns]

# %%
df2['altura'][19]
# Out:
# 172.0

# %%
df2['altura'][19] = 1.72
# Out:
# /home/usuario/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['altura'][19]
# Out:
# 1.72

# %%
df2['altura'].mean()
# Out:
# 1.7129166666666675

# %%
df2.describe()
# Out:
#           altura  Seu peso aproximado em kg      Idade
# count  72.000000                  70.000000  75.000000
# mean    1.712917                  71.071429  24.533333
# std     0.078335                  16.165199   6.973567
# min     1.500000                  32.000000  17.000000
# 25%     1.657500                  60.000000  19.000000
# 50%     1.715000                  70.000000  23.000000
# 75%     1.772500                  79.500000  29.000000
# max     1.890000                 140.000000  53.000000

# %%
df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4b29150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4b3bed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4afa4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4aacc10>]],
#       dtype=object)

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4b513d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f49bf950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4969e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6f4927950>]],
#       dtype=object)

# %%
print("Altura")
print("Mediana:",df2['altura'].median())
print("Media:",df2['altura'].mean())
print("Desvio Padrão:",df2['altura'].std())
# Out:
# Mediana: 1.7149999999999999
# Media: 1.7129166666666675
# Desvio Padrão: 0.07833545596964271

# %%
print("Idade")
print("Mediana:",df2['Idade'].median())
print("Media:",df2['Idade'].mean())
print("Desvio Padrão:",df2['Idade'].std())
print("Qtd de elementos:", len(df2))
# Out:
# Idade
# Mediana: 23.0
# Media: 24.533333333333335
# Desvio Padrão: 6.973566564580182

# %%
# eliminando extremos ( outliers )
x = df2['altura']
x = x[x.between(x.quantile(.15), x.quantile(.85))]

# %%
print("Media:",x.mean())
print("Mediana:",x.me())
print("Desvio:",x.std())
print("Qtd de elementos:", len(x))
# Out:
# Media: 1.718703703703704
# Desvio: 0.04895305014091804
