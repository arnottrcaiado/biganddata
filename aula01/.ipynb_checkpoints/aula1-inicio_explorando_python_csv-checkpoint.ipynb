# %%
# Abrindo e tratando dados .csv
# principios
# Prof. Arnott Ramos Caiado
# set-2020

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# verificando localização e conteúdo da(s) pasta(s)

# %%
! pwd
# Out:
# /home/usuario/Google Drive/DATASCIENCE/facsenac/biganddata/aula01

# %%
! ls -la ../../dados
# Out:
# total 205488
# drwxrwxr-x 2 usuario usuario      4096 set  9 15:55 .
# drwxrwxr-x 6 usuario usuario      4096 set  3 03:58 ..
# -rw-rw-r-- 1 usuario usuario     25419 set  9 15:03 Pesq_alunos_ntrat.csv
# -rw-rw-r-- 1 usuario usuario     25436 set  9 15:53 Pesq_alunos_trat.csv
# -rw-rw-r-- 1 usuario usuario  95813321 set  1 18:11 PNAD_COVID_062020.csv
# -rw-rw-r-- 1 usuario usuario 114533014 set  1 18:11 PNAD_COVID_072020.csv
# -rw-rw-r-- 1 usuario usuario       380 set  2 04:10 tabela_uf.csv

# %%
# variavel com o caminho (path) e o nome do arquivo

# %%
dados = "../../dados/Pesq_alunos_trat.csv"
dados_sujos = "../../dados/Pesq_alunos_ntrat.csv"

# %%
# criando um dataframe pandas com o resultado do arquivo .csv

# %%
df = pd.read_csv( dados )
df2 = pd.read_csv( dados_sujos )

# %%
df.shape # tamanho do dataframe - 75 linhas por 13 colunas
df2.shape
# Out:
# (75, 13)

# %%
# mostrando as primeiras 10 linhas para conhecer um pouco

# %%
df.head(10)
# Out:
#   Sexo Estado Civil  \
# 0    F     Viuvo(a)
# 1    M  Solteiro(a)
# 2    M  Solteiro(a)
# 3    M    Namorando
# 4    M  Solteiro(a)
# 5    F  Solteiro(a)
# 6    M        Noivo
# 7    M  Solteiro(a)
# 8    M    Namorando
# 9    F  Solteiro(a)
#
#   Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )  \
# 0                                               1,67
# 1                                               1,74
# 2                                                1,7
# 3                                               1,89
# 4                                                1,8
# 5                                               1,63
# 6                                               1,83
# 7                                               1,67
# 8                                                1,6
# 9                                               1,65
#
#    Seu peso aproximado em kg  Idade      Curso#Periodo/Turno  \
# 0                       70.0     27  ADS#2Manha-PortoDigital
# 1                       68.0     22  ADS#2Manha-PortoDigital
# 2                       55.0     18  ADS#2Manha-PortoDigital
# 3                       60.0     19  ADS#2Manha-PortoDigital
# 4                       60.0     17  ADS#2Manha-PortoDigital
# 5                       58.0     20  ADS#2Manha-PortoDigital
# 6                       66.0     23  ADS#2Manha-PortoDigital
# 7                       80.0     27  ADS#2Manha-PortoDigital
# 8                       68.0     18  ADS#2Manha-PortoDigital
# 9                       64.0     18  ADS#2Manha-PortoDigital
#
#   Situação atual de trabalho  \
# 0           Estudando Apenas
# 1           Estudando Apenas
# 2           Estudando Apenas
# 3           Estudando Apenas
# 4           Estudando Apenas
# 5           Estudando Apenas
# 6           Estudando Apenas
# 7                Trabalhando
# 8           Estudando Apenas
# 9           Estudando Apenas
#
#   Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                               Java
# 1                    JavaScript, Python, PHP, C, C++
# 2                                   Java, JavaScript
# 3                        JavaScript, Python, C#, C++
# 4       Java, JavaScript, Python, R, PHP, C, C#, C++
# 5                        JavaScript, Python, PHP, C#
# 6                  Java, JavaScript, Python, PHP, C#
# 7                       Java, JavaScript, Python, C#
# 8                  Java, JavaScript, Python, PHP, C#
# 9                  Java, JavaScript, Python, PHP, C#
#
#   O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                  Estudar e correr
# 1                                 Exercícios físicos
# 2  Assistir filmes e conversar online com meus am...
# 3                                 Teatro e jogar lol
# 4               Arriscar no desenvolvimento de sites
# 5                                            Pedalar
# 6      Assistir filmes de ação e praticar musculação
# 7                      Continuar meus jogos de Vôlei
# 8          Jogar com amigos, assistir com a fámilia
# 9  Assistir filmes/séries e ir à praia quando for...
#
#   Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                         SmartPhone
# 1                               SmartPhone, NoteBook
# 2                               SmartPhone, NoteBook
# 3  SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                               SmartPhone, NoteBook
# 5                               SmartPhone, NoteBook
# 6                               SmartPhone, NoteBook
# 7  SmartPhone, NoteBook, Câmera de Video ( micro ...
# 8  SmartPhone, Micro Desktop, Microfone ( micro o...
# 9                               SmartPhone, NoteBook
#
#   Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                               3 a 5 horas semanais
# 1                               3 a 5 horas semanais
# 2                               3 a 5 horas semanais
# 3                              1 a 15 horas semanais
# 4                              6 a 10 horas semanais
# 5                               1 a 2 horas semanais
# 6  Depende do nível da atividade, houve algumas q...
# 7                               3 a 5 horas semanais
# 8                               3 a 5 horas semanais
# 9                              6 a 10 horas semanais
#
#   Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                  Segurança tecnologia ou pesquisa
# 1            UX/UI design, Desenvolvimento Front-end
# 2                            engenharia de software
# 3                               Programador de jogos
# 4            Na área de desenvolvimento web, backend
# 5                                            backend
# 6  Desenvolvimento mobile, inteligência artificia...
# 7                                  Segurança pública
# 8             Em progrmação web e segurança de dados
# 9    Não tenho certeza ainda, mas penso em Hardware.
#
#   Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                           Nenhum\n
# 1                                             Nenhum
# 2                                 Curso de java 120h
# 3  Curso de html avançado 15h, Desafio quarentena...
# 4                           Licenciatura em Biologia
# 5                                             nenhum
# 6                                       Python (40h)
# 7                             Lógica de programação
# 8                         Desafio quarentena - 60hrs
# 9              Nenhum curso. Mas sempre pesquisando.

# %%
# algumas estatisticas - método describe

# %%
df.describe()
# Out:
#        Seu peso aproximado em kg      Idade
# count                  73.000000  75.000000
# mean                   70.849315  24.533333
# std                    15.863718   6.973567
# min                    32.000000  17.000000
# 25%                    60.000000  19.000000
# 50%                    69.000000  23.000000
# 75%                    78.000000  29.000000
# max                   140.000000  53.000000

# %%
# mostrando um grafico inicial - histograma de idades

# %%
df['Idade'].hist()

# %%
df['Seu peso aproximado em kg'].hist()

# %%
# modificando o nome de colunas para simplificar / facilitar

# %%
df.rename(columns={'Sua altura aproximada ( ex: 1,7 para quem mede um metro e setenta )': 'altura'})
# Out:
#    Sexo Estado Civil  altura  Seu peso aproximado em kg  Idade  \
# 0     F     Viuvo(a)    1,67                       70.0     27
# 1     M  Solteiro(a)    1,74                       68.0     22
# 2     M  Solteiro(a)     1,7                       55.0     18
# 3     M    Namorando    1,89                       60.0     19
# 4     M  Solteiro(a)     1,8                       60.0     17
# ..  ...          ...     ...                        ...    ...
# 70    M  Solteiro(a)     NaN                        NaN     31
# 71    F  Solteiro(a)    1,62                       51.0     19
# 72    M  Solteiro(a)    1,85                       70.0     22
# 73    M  Solteiro(a)  170 CM                       64.0     22
# 74    M  Solteiro(a)     1,7                       62.0     21
#
#         Curso#Periodo/Turno Situação atual de trabalho  \
# 0   ADS#2Manha-PortoDigital           Estudando Apenas
# 1   ADS#2Manha-PortoDigital           Estudando Apenas
# 2   ADS#2Manha-PortoDigital           Estudando Apenas
# 3   ADS#2Manha-PortoDigital           Estudando Apenas
# 4   ADS#2Manha-PortoDigital           Estudando Apenas
# ..                      ...                        ...
# 70               ADS#3Manha           Estudando Apenas
# 71               ADS#3Manha           Estudando Apenas
# 72               ADS#3Manha           Estudando Apenas
# 73               ADS#3Manha           Estudando Apenas
# 74               ADS#3Manha           Estudando Apenas
#
#    Linguagens de programação que vc conhece (pode marcar mais de uma opção )  \
# 0                                                Java
# 1                     JavaScript, Python, PHP, C, C++
# 2                                    Java, JavaScript
# 3                         JavaScript, Python, C#, C++
# 4        Java, JavaScript, Python, R, PHP, C, C#, C++
# ..                                                ...
# 70                                 JavaScript, Python
# 71                                   Java, Python, C#
# 72                                   Java, Python, C#
# 73                                  Java, Python, PHP
# 74                   Java, JavaScript, Python, PHP, C
#
#    O que você pretende fazer ao longo deste semestre como opção de lazer ? ( descreva )  \
# 0                                   Estudar e correr
# 1                                  Exercícios físicos
# 2   Assistir filmes e conversar online com meus am...
# 3                                  Teatro e jogar lol
# 4                Arriscar no desenvolvimento de sites
# ..                                                ...
# 70                Assistir series, jogar vídeo games.
# 71  ler bastante, aprender novas linguagens e algu...
# 72                                Navegar na internet
# 73                                     CRIAR PROJETOS
# 74                                 Aproveitar o tempo
#
#    Equipamento(s) que vc pretende utilizar em casa para as aulas e seus estudos  \
# 0                                          SmartPhone
# 1                                SmartPhone, NoteBook
# 2                                SmartPhone, NoteBook
# 3   SmartPhone, Micro Desktop, Microfone ( micro o...
# 4                                SmartPhone, NoteBook
# ..                                                ...
# 70                               SmartPhone, NoteBook
# 71  NoteBook, Câmera de Video ( micro ou notebook ...
# 72                               SmartPhone, NoteBook
# 73                               SmartPhone, NoteBook
# 74                               SmartPhone, NoteBook
#
#    Quantas horas de estudos semanais você pretende dedicar além das aulas ?  \
# 0                                3 a 5 horas semanais
# 1                                3 a 5 horas semanais
# 2                                3 a 5 horas semanais
# 3                               1 a 15 horas semanais
# 4                               6 a 10 horas semanais
# ..                                                ...
# 70                               3 a 5 horas semanais
# 71                              6 a 10 horas semanais
# 72                               3 a 5 horas semanais
# 73                               1 a 2 horas semanais
# 74                             10 a 15 horas semanais
#
#    Para quais áreas você está direcionando mais a sua formação, pensando na carreira ? ( descreva )  \
# 0                   Segurança tecnologia ou pesquisa
# 1             UX/UI design, Desenvolvimento Front-end
# 2                             engenharia de software
# 3                                Programador de jogos
# 4             Na área de desenvolvimento web, backend
# ..                                                ...
# 70  Ainda estou analisando o que eu irei seguir, m...
# 71           segurança da informação e Dev Full Stack
# 72                               Programação back-end
# 73  BANCO DE DADOS, PREVENÇÃO DE INVASÃO, ÁREAS RE...
# 74  Engenharia civil com foco em projetos de segur...
#
#    Relacione aqui os ultimos cursos que você realizou em 2020-1 e a carga horária ( cursos extra-sala. Se não realizou nenhum, escreva nenhum )
# 0                                            Nenhum\n
# 1                                              Nenhum
# 2                                  Curso de java 120h
# 3   Curso de html avançado 15h, Desafio quarentena...
# 4                            Licenciatura em Biologia
# ..                                                ...
# 70                                            Nenhum.
# 71  webnar - Primeiros passos em oracle (4h)\nOmni...
# 72                                             nenhum
# 73                                    EXCEL AVANÇADO.
# 74                    Bacharelado em Engenharia civil
#
# [75 rows x 13 columns]

# %%
df.head(10)

# %%
# alterando o dataframe com a nova nomenclatura

# %%
df['altura'].hist()
