# %% [markdown]
#  Principios de Estatística com Python
#  Estatística Descritiva
#
#  Prof. Arnott Ramos Caiado
#
#  contagem
#  media
#  mediana
#  desvio padrão
#  minimo
#  maximo
#
#  histograma
#  grafico de barras
#  grafico de linhas

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/usuario/Google Drive/DATASCIENCE/facsenac/biganddata/aula-estatistica-decritiva

# %%
arquivo = "../../dados/PNAD_COVID_072020.csv"
df = pd.read_csv( arquivo, sep="," )

# %%
df.shape
# Out:
# (384166, 145)

# %%
df.head(10)
# Out:
#     Ano  UF  CAPITAL  RM_RIDE  V1008  V1012  V1013  V1016  Estrato        UPA  \
# 0  2020  11     11.0      NaN      1      4      7      3  1110011  110015970
# 1  2020  11     11.0      NaN      1      4      7      3  1110011  110015970
# 2  2020  11     11.0      NaN      1      4      7      3  1110011  110015970
# 3  2020  11     11.0      NaN      1      4      7      3  1110011  110015970
# 4  2020  11     11.0      NaN      2      1      7      3  1110011  110015970
# 5  2020  11     11.0      NaN      4      4      7      3  1110011  110015970
# 6  2020  11     11.0      NaN      4      4      7      3  1110011  110015970
# 7  2020  11     11.0      NaN      4      4      7      3  1110011  110015970
# 8  2020  11     11.0      NaN      4      4      7      3  1110011  110015970
# 9  2020  11     11.0      NaN      4      4      7      3  1110011  110015970
#
#    ...  F001  F0021  F0022  F002A1  F002A2  F002A3  F002A4  F002A5  F0061  \
# ...
